# %% [markdown]
# ## GROUP 10 - Memebers NAME
# ### Deepak
# ### Eric
# ### Shreyash

# %% [markdown]
# ###                                   Exploratory Data Analysis on Attrition in an Organization

# %%
# Importing thr libraries required for the EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the Dataset

emp = pd.read_excel("Attrtion_Py.xlsx")

# %%
emp.head(5)
# Out:
#    Age  Age_Group  Attrition     BusinessTravel              Department  \
# 0   41         50          1      Travel_Rarely                   Sales
# 1   49         50          0  Travel_Frequently  Research & Development
# 2   37         40          1      Travel_Rarely  Research & Development
# 3   33         40          0  Travel_Frequently  Research & Development
# 4   27         30          0      Travel_Rarely  Research & Development
#
#   EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0  Life Sciences                        2  Female               3         2
# 1  Life Sciences                        3    Male               2         2
# 2          Other                        4    Male               2         1
# 3  Life Sciences                        4  Female               3         1
# 4        Medical                        1    Male               3         1
#
#    ...  TotalWorkingYears Work_Exp  WorkLifeBalance YearsAtCompany  YatC  \
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Age_Group                1470 non-null   int64
#  2   Attrition                1470 non-null   int64
#  3   BusinessTravel           1470 non-null   object
#  4   Department               1470 non-null   object
#  5   EducationField           1470 non-null   object
#  6   EnvironmentSatisfaction  1470 non-null   int64
#  7   Gender                   1470 non-null   object
#  8   JobInvolvement           1470 non-null   int64
#  9   JobLevel                 1470 non-null   int64
#  10  JobSatisfaction          1470 non-null   int64
#  11  MaritalStatus            1470 non-null   object
#  12  MonthlyIncome            1470 non-null   int64
#  13  OverTime                 1470 non-null   object
# ...

# %% [markdown]
# ### Summary of our Data:
# •	Dataset Structure: 1470 observations (rows), 35 features (variables)
#
# •	Missing Data: Luckily for us, there is no missing data! this will make it easier to work with the dataset.
#
# •	Data Type: We only have two datatypes in this dataset: factors and integers
#
# •	Label/Output: Attrition is the label in our dataset and we would like to find out why employees are leaving the     organization.
#
# •	Imbalanced dataset: 1237 (84% of cases) employees did not leave the organization while 237 (16% of cases) did leave the organization making our dataset to be considered imbalanced since more people stay in the organization than they actually leave.

# %%
# List of variables(Columns)
emp.columns
# Out:
# Index(['Age', 'Age_Group', 'Attrition', 'BusinessTravel', 'Department',
#        'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'OverTime', 'TotalWorkingYears', 'Work_Exp', 'WorkLifeBalance',
#        'YearsAtCompany', 'YatC', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'YatCM',
#        'DistanceFromHome'],
#       dtype='object')

# %% [markdown]
# ### Variable:
#
# Age, Business Travel, Department, Education field, Environment Satisfaction, Gender, Job involvement, Job level, Job satisfaction, Marital Status, Monthly Income, Over time, Total working Hours, Work life-balance, Years at company, Years in current role, Years since last promotion, Years with current manager, Distance from home.

# %% [markdown]
# ### Distribution of our Labels:
# This is an important aspect that will be further discussed in this kernel and that is dealing with imbalanced dataset. 84% of employees did not quit the organization while 16% did leave the organization.

# %%
# Distribution of Labels

print("Total No of employee currently working:", emp[emp["Attrition"]==0].count()["Attrition"])
print("Total No of employee Left the company:", emp[emp["Attrition"]==1].count()["Attrition"])
print("Total No of employee:", ((emp[emp["Attrition"]==0].count()["Attrition"])+(emp[emp["Attrition"]==1].count()["Attrition"])))
# Out:
# Total No of employee currently working: 1233
# Total No of employee Left the company: 237
# Total No of employee: 1470

# %% [markdown]
# ### Analysis on the Basis of Age

# %% [markdown]
# 1. Avrage Distribution Between Male and female
# 2. Average Job satisfaction by Age and gender
# 3. Average Monthly Salay by Age and Gender

# %%
# Average Age Distribution on the basis of Attrition

emp["Age"].describe()
print("The Average Age of Employee is: ", np.round(emp["Age"].mean(),2))
print("The Average Age of Employees with Attrition 1 is:", np.round(emp[emp["Attrition"]==1].mean()["Age"],2))
print("The Average Age of Employees with Attrition 0 is:", np.round(emp[emp["Attrition"]==0].mean()["Age"],2))
sns.distplot(emp["Age"])
# Out:
# The Average Age of Employee is:  36.92
# The Average Age of Employees with Attrition 1 is: 33.61
# The Average Age of Employees with Attrition 0 is: 37.56

# %%
sns.distplot(emp[emp["Attrition"]==1]["Age"])

# %%
sns.distplot(emp[emp["Attrition"]==0]["Age"])

# %% [markdown]
# #### Average Age distribution on the basis of Gender for Attrition 1 and 0

# %%
# Average Distribution of Male with Attrition 1 And 0
print("The Average Age of Male Employee is: ", np.round(emp[emp["Gender"]=="Male"]["Age"].mean(),2))
print("The Average Age of Male Employees with Attrition 1 is:", np.round(emp[(emp["Gender"]=="Male") & (emp["Attrition"]==1)].mean()["Age"],2))
print("The Average Age of Male Employees with Attrition 0 is:", np.round(emp[(emp["Gender"]=="Male") & (emp["Attrition"]==0)].mean()["Age"],2))
# Out:
# The Average Age of Male Employee is:  36.65
# The Average Age of Male Employees with Attrition 1 is: 34.21
# The Average Age of Male Employees with Attrition 0 is: 37.15

# %%
# Distribution Plot
sns.distplot(emp[emp["Gender"]=="Male"]["Age"])

# %%
sns.distplot(emp[(emp["Gender"]=="Male") & (emp["Attrition"]==1)]["Age"])

# %%
sns.distplot(emp[(emp["Gender"]=="Male") & (emp["Attrition"]==0)]["Age"])

# %%
# Average Distribution of Female with Attrition 1 And 0
print("The Average Age of Female Employee is: ", np.round(emp[emp["Gender"]=="Female"]["Age"].mean(),2))
print("The Average Age of Female Employees with Attrition 1 is:", np.round(emp[(emp["Gender"]=="Female") & (emp["Attrition"]==1)].mean()["Age"],2))
print("The Average Age of Female Employees with Attrition 0 is:", np.round(emp[(emp["Gender"]=="Female") & (emp["Attrition"]==0)].mean()["Age"],2))
# Out:
# The Average Age of Female Employee is:  37.33
# The Average Age of Female Employees with Attrition 1 is: 32.57
# The Average Age of Female Employees with Attrition 0 is: 38.16

# %%
# Distribution Plot
sns.distplot(emp[emp["Gender"]=="Female"]["Age"])

# %%
sns.distplot(emp[(emp["Gender"]=="Female") & (emp["Attrition"]==1)]["Age"])

# %%
sns.distplot(emp[(emp["Gender"]=="Female") & (emp["Attrition"]==0)]["Age"])

# %% [markdown]
#  For further Analysis on Age and Gender with other variable like Monthly Salary, Years since last promotion, Distance from Home, Martital Status, Job satisfaction.
#     Age is divided into 4 Categories: age<=30, 30<age<=40, 40<age<=50, 50<age

# %% [markdown]
# ### Analysis between Age, gender, attrition and Monthly Salary
#
#   We will se the attrition rate in different age group for male and female and compare the monthly salary

# %% [markdown]
# #### Attrtiton On the Basis of Age_Group:

# %%
# Attrition On the Basis of Age group
plt.figure(figsize=(12,6))
sns.countplot(x='Attrition',data=emp,hue='Age_Group',palette='viridis')

# %% [markdown]
# #### Bivariate Analysis on Age group and Attrition

# %%
# Bivariate analysis on the between Age and Attrition

Age_Crosstab = pd.crosstab(emp.Age_Group, columns=emp.Attrition)
row_tot = Age_Crosstab.sum(axis=1)
Age_Crosstab_prop = round(Age_Crosstab.div(row_tot,axis=0)*100)
print("The proportion of Artrition in different Age Group is: ")
print(Age_Crosstab_prop)
Age_Crosstab_prop.plot(kind = 'bar' ,rot=0 , figsize = [16,5])
# Out:
# The proportion of Artrition in different Age Group is:
# Attrition     0     1
# Age_Group
# 30         74.0  26.0
# 40         86.0  14.0
# 50         89.0  11.0
# 60         87.0  13.0

# %% [markdown]
# <b>We can se 26% attrtition in Age Group less tha 30 years and 14% in age group 30  to 40

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %%
Avg_Income = emp.groupby(["Age_Group","Attrition"]).mean()["MonthlyIncome"].unstack()
Avg_Income["Difference%"] = np.round(((Avg_Income[1] - Avg_Income[0])/Avg_Income[0])*100)
Avg_Income["PropO"] = np.round((Avg_Income[0]/(Avg_Income[0]+Avg_Income[1]))*100)
Avg_Income["Prop1"] = np.round((Avg_Income[1]/(Avg_Income[0]+Avg_Income[1]))*100)
print(Avg_Income)
#Avg_Income.plot(kind = 'bar',rot=0, figsize=[16,7])
# Out:
# Attrition             0            1  Difference%  PropO  Prop1
# Age_Group
# 30          4142.916084  3077.220000        -26.0   57.0   43.0
# 40          6000.850187  5039.317647        -16.0   54.0   46.0
# 50          9316.736111  7014.382353        -25.0   57.0   43.0
# 60         10817.760000  8888.222222        -18.0   55.0   45.0

# %%
Avg_Income_Prop = Avg_Income.copy()
del Avg_Income_Prop[0]
del Avg_Income_Prop[1]

Avg_Income_Prop.plot(kind = 'bar' ,rot=0 , figsize = [16,5])

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### We will Further see If Gender is Affecting the Attrition

# %%
# Subsetting the data into employee on the basis of Gender

emp_Male = emp[emp["Gender"] == "Male"]
emp_Female = emp[emp["Gender"] == "Female"]

# %%
# Bivariate analysis on the between Male Employees and Attrition

Male_Crosstab = pd.crosstab(emp_Male.Age_Group, columns=emp_Male.Attrition)
row_tot = Male_Crosstab.sum(axis=1)
Male_Crosstab_prop = round(Male_Crosstab.div(row_tot,axis=0)*100)
Male_Crosstab_prop
# Out:
# Attrition     0     1
# Age_Group
# 30         75.0  25.0
# 40         85.0  15.0
# 50         89.0  11.0
# 60         84.0  16.0

# %%
Avg_Income_Male
# Out:
# Attrition             0            1  Difference%
# Age_Group
# 30          3975.955801  2938.355932        -26.0
# 40          5963.686901  5331.000000        -11.0
# 50          9323.279070  6554.904762        -30.0
# 60         10881.030303  8053.153846        -26.0

# %%
# Bivariate analysis on the between Female Employees and Attrition

Female_Crosstab = pd.crosstab(emp_Female.Age_Group, columns=emp_Female.Attrition)
row_tot = Female_Crosstab.sum(axis=1)
Female_Crosstab_prop = round(Female_Crosstab.div(row_tot,axis=0)*100)
Female_Crosstab_prop
# Out:
# Attrition     0     1
# Age_Group
# 30         72.0  28.0
# 40         89.0  11.0
# 50         90.0  10.0
# 60         92.0   8.0

# %%
Avg_Income_Female = emp_Female.groupby(["Age_Group","Attrition"]).mean()["MonthlyIncome"].unstack()
Avg_Income_Female["Difference%"] = np.round(((Avg_Income_Female[1] - Avg_Income_Female[0])/Avg_Income_Female[0])*100)
Avg_Income_Female
# Out:
# Attrition             0             1  Difference%
# Age_Group
# 30          4430.723810   3277.048780        -26.0
# 40          6053.484163   4445.535714        -27.0
# 50          9307.034483   7756.615385        -17.0
# 60         10746.983051  11059.400000          3.0

# %% [markdown]
# <b> There is no major difference in attriton in terms of Gender. Attrition is almost equally spread among both male and female.
#     But, We can conclude that Monthly income is likely to be affectinag Attrition in all the age group. There is Significant difference in the salary of the employees who left the company in comparision to the employee who are woking in all the age groups.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b> We further do the Attrition analysis on the basis of Marital Status in different age group in Male and Female and Try to find the reason for the Attrition

# %% [markdown]
# We will see the Attrition percent single, married and divorce on the basis of Age group.

# %%
# Joint Proportion analysis on Age Group and Marital Status 

marital_crosstab = pd.crosstab([emp.Age_Group,emp.MaritalStatus], columns=emp.Attrition)
row_tot = marital_crosstab.sum(axis=1)
marital_crosstab_prop = round(marital_crosstab.div(row_tot,axis=0)*100)
marital_crosstab_prop
# Out:
# Attrition                   0     1
# Age_Group MaritalStatus
# 30        Divorced       87.0  13.0
#           Married        81.0  19.0
#           Single         60.0  40.0
# 40        Divorced       90.0  10.0
#           Married        89.0  11.0
#           Single         79.0  21.0
# 50        Divorced       90.0  10.0
#           Married        91.0   9.0
#           Single         86.0  14.0
# 60        Divorced       96.0   4.0
#           Married        88.0  12.0
#           Single         80.0  20.0

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------

# %%
# Joint Proportion analysis on Age Group and Marital Status for Male

marital_Mcrosstab = pd.crosstab([emp_Male.Age_Group,emp_Male.MaritalStatus], columns=emp_Male.Attrition)
row_tot = marital_Mcrosstab.sum(axis=1)
marital_Mcrosstab_prop = round(marital_crosstab.div(row_tot,axis=0)*100)
marital_Mcrosstab_prop
# Out:
# Attrition                   0     1
# Age_Group MaritalStatus
# 30        Divorced       86.0  14.0
#           Married        83.0  17.0
#           Single         61.0  39.0
# 40        Divorced       90.0  10.0
#           Married        85.0  15.0
#           Single         79.0  21.0
# 50        Divorced       86.0  14.0
#           Married        92.0   8.0
#           Single         87.0  13.0
# 60        Divorced       94.0   6.0
#           Married        90.0  10.0
#           Single         64.0  36.0

# %%
# Joint Proportion analysis on Age Group and Marital Status fpr Female

marital_Fcrosstab = pd.crosstab([emp_Female.Age_Group,emp_Female.MaritalStatus], columns=emp_Female.Attrition)
row_tot = marital_Fcrosstab.sum(axis=1)
marital_Fcrosstab_prop = round(marital_Fcrosstab.div(row_tot,axis=0)*100)
marital_Fcrosstab_prop
# Out:
# Attrition                    0     1
# Age_Group MaritalStatus
# 30        Divorced        87.0  13.0
#           Married         76.0  24.0
#           Single          60.0  40.0
# 40        Divorced        91.0   9.0
#           Married         95.0   5.0
#           Single          80.0  20.0
# 50        Divorced        97.0   3.0
#           Married         89.0  11.0
#           Single          85.0  15.0
# 60        Divorced       100.0   0.0
#           Married         86.0  14.0
#           Single         100.0   0.0

# %%
# Plotting Attrtion Against Marital Status and Age Group
marital_crosstab_prop.plot(kind = 'bar' ,rot=0 , figsize = [16,5])

# %% [markdown]
# #### Summary:
# From the above table we can clearly see the Attrition is High for Singles in Age group below 30 (40%) and 30 to 40(21%). Singles are likely to leave company in their early age of Job.
#
# We will further see below what are the various factors we may be responsible for his attrition in Single male and female.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Monthly Income

# %%
emp_MI= emp.groupby(["Age_Group","MaritalStatus","Attrition"]).mean()["MonthlyIncome"].unstack()
emp_MI["Difference%"] = np.round(((emp_MI[1] - emp_MI[0])/emp_MI[0])*100)
emp_MI
# Out:
# Attrition                           0            1  Difference%
# Age_Group MaritalStatus
# 30        Divorced        4409.436620  2584.000000        -41.0
#           Married         4220.920000  3254.400000        -23.0
#           Single          3824.322222  3079.084746        -19.0
# 40        Divorced        6398.688525  5267.615385        -18.0
#           Married         5668.720930  5693.838710          0.0
#           Single          6242.103896  4472.048780        -28.0
# 50        Divorced        9408.378378  5103.125000        -46.0
#           Married        10093.235714  7707.357143        -24.0
#           Single          7756.040541  7480.083333         -4.0
# 60        Divorced       10706.592593  2380.000000        -78.0
#           Married        10636.393939  9433.000000        -11.0
#           Single         11285.625000  9088.875000        -19.0

# %%
# For Male Employees MonthlyIncome Difference

emp_MI_M= emp_Male.groupby(["Age_Group","MaritalStatus","Attrition"]).mean()["MonthlyIncome"].unstack()
emp_MI_M["Difference%"] = np.round(((emp_MI_M[1] - emp_MI_M[0])/emp_MI_M[0])*100)
emp_MI_M
# Out:
# Attrition                           0            1  Difference%
# Age_Group MaritalStatus
# 30        Divorced        4222.863636  2480.571429        -41.0
#           Married         3988.192771  3182.529412        -20.0
#           Single          3755.962963  2911.314286        -22.0
# 40        Divorced        6490.265060  5786.888889        -11.0
#           Married         5472.513699  6074.880000         11.0
#           Single          6297.083333  4344.043478        -31.0
# 50        Divorced       10174.595238  5435.285714        -47.0
#           Married        10028.559524  7077.857143        -29.0
#           Single          7258.086957  7151.571429         -1.0
# 60        Divorced        9729.470588  2380.000000        -76.0
#           Married        10511.971429  7400.000000        -30.0
#           Single         13202.000000  9088.875000        -31.0

# %%
# For Female Employees MonthlyIncome Difference

emp_MI_F= emp_Female.groupby(["Age_Group","MaritalStatus","Attrition"]).mean()["MonthlyIncome"].unstack()
emp_MI_F["Difference%"] = np.round(((emp_MI_F[1] - emp_MI_F[0])/emp_MI_F[0])*100)
emp_MI_F
# Out:
# Attrition                           0             1  Difference%
# Age_Group MaritalStatus
# 30        Divorced        4713.481481   2765.000000        -41.0
#           Married         4680.833333   3348.384615        -28.0
#           Single          3926.861111   3323.750000        -15.0
# 40        Divorced        6203.794872   4099.250000        -34.0
#           Married         5924.491071   4106.166667        -31.0
#           Single          6176.128571   4635.611111        -25.0
# 50        Divorced        8402.718750   2778.000000        -67.0
#           Married        10190.250000   8336.857143        -18.0
#           Single          8574.107143   7940.000000         -7.0
# 60        Divorced       12367.700000           NaN          NaN
#           Married        10776.870968  11059.400000          3.0
#           Single          9795.111111           NaN          NaN

# %%
emp_MI.plot(kind = 'barh' ,rot=0 , figsize = [16,5])

# %% [markdown]
# #### Conclusion:
# From the above table we can say that Monthly Income is likely to be the reason for the high attrition in the Age group below 30 and 30 to 40 for singles. There is arround 15-25% difference in salary in the age group below 30 between attrtion 1 and 0

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Distance From Home

# %%
# Analysing difference in Average Distance from home for all the employees on the basis of Agr Group

emp_DFH= emp.groupby(["Age_Group","MaritalStatus","Attrition"]).mean()["DistanceFromHome"].unstack()
emp_DFH["Difference%"] = np.round(((emp_DFH[1] - emp_DFH[0])/emp_DFH[0])*100)
emp_DFH
# Out:
# Attrition                        0          1  Difference%
# Age_Group MaritalStatus
# 30        Divorced       10.422535  10.000000         -4.0
#           Married         9.496000  10.633333         12.0
#           Single          7.922222   9.864407         25.0
# 40        Divorced        8.254098  11.846154         44.0
#           Married         9.093023  12.064516         33.0
#           Single          7.824675  10.853659         39.0
# 50        Divorced        8.432432  11.125000         32.0
#           Married         9.407143  12.285714         31.0
#           Single          9.945946  10.333333          4.0
# 60        Divorced        9.370370   2.000000        -79.0
#           Married         8.818182   7.666667        -13.0
#           Single          8.843750  10.000000         13.0

# %%
emp_DFH.plot(kind = 'bar' ,rot=0 , figsize = [16,5])

# %%
# Subsetting fro All Male employees

emp_DFH_M= emp_Male.groupby(["Age_Group","MaritalStatus","Attrition"]).mean()["DistanceFromHome"].unstack()
emp_DFH_M["Difference%"] = np.round(((emp_DFH_M[1] - emp_DFH_M[0])/emp_DFH_M[0])*100)
emp_DFH_M
# Out:
# Attrition                        0          1  Difference%
# Age_Group MaritalStatus
# 30        Divorced       11.636364  11.000000         -5.0
#           Married         9.156627   7.470588        -18.0
#           Single          7.777778  10.685714         37.0
# 40        Divorced        7.939759  10.888889         37.0
#           Married         9.383562  12.440000         33.0
#           Single          7.559524  11.217391         48.0
# 50        Divorced        8.880952  12.428571         40.0
#           Married         9.011905  10.000000         11.0
#           Single         10.000000   9.285714         -7.0
# 60        Divorced       10.117647   2.000000        -80.0
#           Married         8.257143   5.250000        -36.0
#           Single          8.571429  10.000000         17.0

# %%
# Subsetting fro All Female employees

emp_DFH_F= emp_Female.groupby(["Age_Group","MaritalStatus","Attrition"]).mean()["DistanceFromHome"].unstack()
emp_DFH_F["Difference%"] = np.round(((emp_DFH_F[1] - emp_DFH_F[0])/emp_DFH_F[0])*100)
emp_DFH_F
# Out:
# Attrition                        0          1  Difference%
# Age_Group MaritalStatus
# 30        Divorced        8.444444   8.250000         -2.0
#           Married        10.166667  14.769231         45.0
#           Single          8.138889   8.666667          6.0
# 40        Divorced        8.923077  14.000000         57.0
#           Married         8.714286  10.500000         20.0
#           Single          8.142857  10.388889         28.0
# 50        Divorced        7.843750   2.000000        -75.0
#           Married        10.000000  14.571429         46.0
#           Single          9.857143  11.800000         20.0
# 60        Divorced        8.100000        NaN          NaN
#           Married         9.451613   9.600000          2.0
#           Single          9.055556        NaN          NaN

# %% [markdown]
# #### Conclusion:
# From the above table and graph we can se that Distance from home is affecting the attrition in all the age group, majorly in below 30 and 30 to 40 Single Male.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Over Time

# %% [markdown]
# For the below Ananlysis we have subset the data set into employee with atttrtion 1 and employee with Attrition 0.
# The we try to find the pattern for the no of employee with "Yes" in over time for attrition 1 and 0

# %%
# Subsetting the Data on the basis of Attrition 0 and 1

emp_at0 = emp[emp["Attrition"] == 0]
emp_at1 = emp[emp["Attrition"] == 1]

# %%
# Analysing over time in different Age Group for Attriton 0

OT0_Crosstab = pd.crosstab([emp_at0.Age_Group, emp_at0.MaritalStatus, emp_at0.Gender], columns=[emp_at0.Attrition,emp_at0.OverTime])
row_tot = OT0_Crosstab.sum(axis=1)
OT0_Crosstab_prop = round(OT0_Crosstab.div(row_tot,axis=0)*100)
#OT0_Crosstab
OT0_Crosstab_prop
# Out:
# Attrition                          0
# OverTime                          No   Yes
# Age_Group MaritalStatus Gender
# 30        Divorced      Female  81.0  19.0
#                         Male    82.0  18.0
#           Married       Female  74.0  26.0
#                         Male    83.0  17.0
#           Single        Female  75.0  25.0
#                         Male    89.0  11.0
# 40        Divorced      Female  64.0  36.0
#                         Male    82.0  18.0
#           Married       Female  77.0  23.0
#                         Male    75.0  25.0
#           Single        Female  79.0  21.0
#                         Male    86.0  14.0
# 50        Divorced      Female  59.0  41.0
#                         Male    67.0  33.0
#           Married       Female  71.0  29.0
#                         Male    74.0  26.0
#           Single        Female  68.0  32.0
#                         Male    83.0  17.0
# 60        Divorced      Female  60.0  40.0
# ...

# %%
OT0_Crosstab_prop.plot(kind = 'barh' ,rot=0 , figsize = [20,20])

# %%
# Analysing over time in different Age Group for Attriton 0

OT1_Crosstab = pd.crosstab([emp_at1.Age_Group, emp_at1.MaritalStatus, emp_at1.Gender], columns=[emp_at1.Attrition,emp_at1.OverTime])
row_tot = OT1_Crosstab.sum(axis=1)
OT1_Crosstab_prop = round(OT1_Crosstab.div(row_tot,axis=0)*100)
#OT1_Crosstab
OT1_Crosstab_prop
# Out:
# Attrition                          1
# OverTime                          No    Yes
# Age_Group MaritalStatus Gender
# 30        Divorced      Female  25.0   75.0
#                         Male    57.0   43.0
#           Married       Female  38.0   62.0
#                         Male    41.0   59.0
#           Single        Female  46.0   54.0
#                         Male    54.0   46.0
# 40        Divorced      Female  25.0   75.0
#                         Male    56.0   44.0
#           Married       Female  50.0   50.0
#                         Male    48.0   52.0
#           Single        Female  50.0   50.0
#                         Male    35.0   65.0
# 50        Divorced      Female   0.0  100.0
#                         Male    43.0   57.0
#           Married       Female  86.0   14.0
#                         Male    43.0   57.0
#           Single        Female  20.0   80.0
#                         Male    43.0   57.0
# 60        Divorced      Male     0.0  100.0
# ...

# %%
OT1_Crosstab_prop.plot(kind = 'barh' ,rot=0 , figsize = [20,20],)
plt.tight_layout()

# %% [markdown]
# #### Conclusion:
# Form the abopve graph and proportion table we can see that proportion of Employee doing over time is high in Attrtion 1 as comapare to attrition 0

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Summary:
#
# <b>
# 1. From the above analysis we can say that Age is one the Varriable which is affection the Attrition.
#
# 2. Attrition on the basis of Gender only is not Conclusive, as attriton is evenly dstributed among the Gender.
#
# 3. Attrtion on the basis of Martail status: Maximum Attrition is in the Single category for Male and female both in the        Age group of below 30 and 30 to 40.
#
# 4. Factors supporting the attrition as per the above points are Monthly Income, Distance From Home and Over time.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Year working With Current Manager

# %% [markdown]
# <b>In this we will see if Employee are affected by the working under One Manager and If it is effecting the Attrition

# %% [markdown]
# We have sub-set the Data on the basis of Attrition. emp_at0 and emp_at1

# %% [markdown]
# We have grouped the Total working years, Years  in the company and Years with the current manager

# %%
# Analysis on Years with Current Manager for Deaprtmetn and Job level for Attriton 1

x1 = emp_at1.groupby(["Department","JobLevel","YatCM"]).count()["Attrition"].unstack()
row_totX1 = x1.sum(axis=1)

x1_prop = round(x1.div(row_totX1,axis=0)*100,2)
x1_prop
# Out:
# YatCM                              0-2  10-20     3-5   5-10
# Department             JobLevel
# Human Resources        1         90.00    NaN   10.00    NaN
#                        3         50.00    NaN     NaN  50.00
# Research & Development 1         69.31   0.99   14.85  14.85
#                        2         40.00    NaN   13.33  46.67
#                        3         23.08    NaN   15.38  61.54
#                        4           NaN    NaN  100.00    NaN
#                        5           NaN    NaN   33.33  66.67
# Sales                  1         90.62    NaN    6.25   3.12
#                        2         56.76    NaN   24.32  18.92
#                        3         35.29    NaN    5.88  58.82
#                        4         25.00  25.00     NaN  50.00
#                        5           NaN  50.00     NaN  50.00

# %%
# Analysis on Years with Current Manager for Deaprtmetn and Job level for Attriton 0

x2 = emp_at0.groupby(["Department","JobLevel","YatCM"]).count()["Attrition"].unstack()
row_totX2 = x2.sum(axis=1)

x2_prop = round(x2.div(row_totX2,axis=0)*100,2)
x2_prop
# Out:
# YatCM                              0-2  10-20    3-5   5-10
# Department             JobLevel
# Human Resources        1         47.83    NaN  34.78  17.39
#                        2         46.15    NaN  15.38  38.46
#                        3         25.00    NaN  25.00  50.00
#                        4           NaN    NaN  25.00  75.00
#                        5         28.57    NaN  14.29  57.14
# Research & Development 1         61.56   1.20  22.82  14.41
#                        2         37.22   4.51  18.42  39.85
#                        3         28.45  11.21  13.79  46.55
#                        4         37.31  11.94  13.43  37.31
#                        5         26.09  19.57  13.04  41.30
# Sales                  1         90.91    NaN    NaN   9.09
#                        2         34.98   2.96  28.57  33.50
#                        3         31.82  12.12  12.12  43.94
#                        4         26.67  23.33   6.67  43.33
# ...

# %%
# Analysing the Factors from Department "R&D", Job level 1 and year wuth Manager 0-2 for Attrition 0

emp_at0[(emp_at0["Department"] == "Research & Development") & (emp_at0["JobLevel"] == 1) & (emp_at0["YatCM"] == "0-2")].describe()
# Out:
#               Age   Age_Group  Attrition  EnvironmentSatisfaction  \
# count  205.000000  205.000000      205.0               205.000000
# mean    33.078049   37.951220        0.0                 2.824390
# std      8.941737    8.557623        0.0                 1.079393
# min     18.000000   30.000000        0.0                 1.000000
# 25%     27.000000   30.000000        0.0                 2.000000
# 50%     32.000000   40.000000        0.0                 3.000000
# 75%     38.000000   40.000000        0.0                 4.000000
# max     59.000000   60.000000        0.0                 4.000000
#
#        JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# count      205.000000     205.0       205.000000     205.000000
# mean         2.809756       1.0         2.868293    2809.482927
# std          0.691618       0.0         1.078861     758.400546
# min          1.000000       1.0         1.000000    1051.000000
# ...

# %%
# Analysing the Factors from Department "R&D", Job level 1 and year wuth Manager 0-2 for Attrition 0


emp_at1[(emp_at1["Department"] == "Research & Development") & (emp_at1["JobLevel"] == 1) & (emp_at1["YatCM"] == "0-2")].describe()
# Out:
#              Age  Age_Group  Attrition  EnvironmentSatisfaction  \
# count  70.000000  70.000000       70.0                70.000000
# mean   30.128571  35.571429        1.0                 2.542857
# std     9.039240   8.450318        0.0                 1.200069
# min    18.000000  30.000000        1.0                 1.000000
# 25%    24.000000  30.000000        1.0                 1.000000
# 50%    28.500000  30.000000        1.0                 3.000000
# 75%    33.750000  40.000000        1.0                 4.000000
# max    58.000000  60.000000        1.0                 4.000000
#
#        JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# count       70.000000      70.0        70.000000      70.000000
# mean         2.500000       1.0         2.528571    2601.814286
# std          0.675664       0.0         1.138540     747.158953
# min          1.000000       1.0         1.000000    1009.000000
# 25%          2.000000       1.0         1.000000    2293.000000
# ...

# %% [markdown]
# ### Conclusion:
# <b>
# From the above Table we can see that Avg year of  working under manager for attrition 0 is 1.23 Years and same for the Attrition 1 is arround 8 months for employee in the intital level of their jobs
# We can say that Year with Worlking ubder manager is likely to affect the attrition in the early part of the carrer of the employees.
# Further we have plotted the graph for Employees for different level of experience in the company aganist the working under the manager which can further show that Year working with Manager is likely to affect the Attrition.

# %%
plt.subplots(figsize=(12,6))
sns.barplot(data= emp_at1, x="JobLevel",y="YearsWithCurrManager", hue="YatC")

# %%
plt.subplots(figsize=(12,6))
sns.barplot(data= emp_at0, x="JobLevel",y="YearsWithCurrManager", hue="YatC")

# %% [markdown]
# ### Summary:
# <b>
# 1. 30% Attrition in Dept > Job level 1> less than 2 year with manager.
#
# 2. Out of 237 employees who left the company 133 were from R& D department and 92 from sales department
#
# 3. Out of 133 from R&D, 101 left at the intital Job level 1.
#
# 4. Out of 101, 70 has left in first 2 years of working under manager.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
at = pd.read_csv("attrition.csv")
at.head(2)
# Out:
#    Age  Attrition     BusinessTravel              Department EducationField  \
# 0   41          1      Travel_Rarely                   Sales  Life Sciences
# 1   49          0  Travel_Frequently  Research & Development  Life Sciences
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
#
#   MaritalStatus  MonthlyIncome OverTime  TotalWorkingYears  WorkLifeBalance  \
# 0        Single           5993      Yes                  8                1
# 1       Married           5130       No                 10                3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
#
#    YearsWithCurrManager  DistanceFromHome
# ...

# %% [markdown]
# # LET'S SEE HOW JOB LEVEL AFFECTS

# %%
att = pd.crosstab(at.JobLevel , columns = at.Attrition)
att
# Out:
# Attrition    0    1
# JobLevel
# 1          400  143
# 2          482   52
# 3          186   32
# 4          101    5
# 5           64    5

# %%
rowsum = att.sum(axis = 1)
x = round(att.div(rowsum/100 , axis = 0))
print(x)    ## row sum is 100
print('horizontal percentage')
print('\n')
columnsum = att.sum(axis = 0)
y = round(att.div(columnsum/100 , axis = 1))
print(y)
print('vertical percentage')
# Out:
# Attrition     0     1
# JobLevel
# 1          74.0  26.0
# 2          90.0  10.0
# 3          85.0  15.0
# 4          95.0   5.0
# 5          93.0   7.0
# horizontal percentage
#
#
# Attrition     0     1
# JobLevel
# 1          32.0  60.0
# 2          39.0  22.0
# 3          15.0  14.0
# 4           8.0   2.0
# 5           5.0   2.0
# vertical percentage

# %%
y.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# ## Job Level 1 is showing highest attiration

# %%
plt.subplots(figsize=(18,7))
sns.countplot(data= at, x="TotalWorkingYears",hue="Attrition",palette='colorblind')

# %% [markdown]
# # we can clearly see
# ###  Attrition at job level 1 is 60% of those who left company
# ### penetration of employees at job level 2 increased due to attrition
# ### Among employees freshers left the company within 2 years most. then we can see attiration at 10 years
# # lets see why attrition at job level 1

# %%
jl1 = at[at.JobLevel == 1]
plt.subplots(figsize=(12,5))
sns.countplot(data= jl1, x="YearsAtCompany",hue="Attrition",palette='colorblind')

# %% [markdown]
# ### Above graph is between job level 1 and years at company of employees  who left the company
# ### we can clearly see most of the people left company within 2 years
# ### Company should foucs on newjoinigs because they are the once leaving company most

# %%
ms = pd.crosstab(at.Attrition , columns = at.MaritalStatus)
ms
# Out:
# MaritalStatus  Divorced  Married  Single
# Attrition
# 0                   294      589     350
# 1                    33       84     120

# %%
ms.plot(kind = 'bar' ,rot=0 , figsize = [16,5])

# %% [markdown]
# ## Among Employees who left the company we can clearly see that single left the company
# ## lets see why single left company most

# %%
pe = at[at.Attrition == 1]
msjl = pd.crosstab(pe.JobLevel , columns = pe.MaritalStatus)
print(msjl)
print('\n')
plt.imshow(msjl)
plt.show()
# Out:
# MaritalStatus  Divorced  Married  Single
# JobLevel
# 1                    23       42      78
# 2                     5       21      26
# 3                     4       17      11
# 4                     1        1       3
# 5                     0        3       2

# %% [markdown]
# ### the right corner yellow box we can clearly see is odd one out why ?
# ### that box reflect the singles working at job level 1 who  left company most

# %%
jl1pe = pe[pe.JobLevel ==1]

# %%
plt.subplots(figsize=(20,6))
sns.countplot(data= pe , x="JobLevel",hue="DistanceFromHome",palette='colorblind')

# %% [markdown]
# ## Job level and distance from home

# %%
pe.boxplot(column = 'MonthlyIncome' , by =  'JobLevel' , figsize = (20,8))

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### we can clearly see job level and monthly income difference
# ### Difference of monthly income between job level 1 and job level 2 is huge

# %%
pe.boxplot(column = 'JobSatisfaction' , by =  'DistanceFromHome' , figsize = (20,8) , grid = False)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## This is a box plot job satisfaction and distace from home of employees who lef the company
# ## we can clearly see employees having larger distance from home has overall less job satisfaction

# %% [markdown]
# # SUMMARY
#
# ## ARRIRATION Because of JOB LEVEL
# ### Factors Affecting Job level
# ### Job Level 1
# ### Maritial Status -- Single
# ### New Joining
# ### Years at Company
# ### Low Monthly Income
#
#
# ## People having larger distance  from home has overall less job satisfaction

# %% [markdown]
# # LET'S SEE HOW EACH DEPARTMENT AFFECTS

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Eric\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
os.chdir(r'C:\Users\Eric\Downloads')

# %%
import pandas as pd
attr = pd.read_csv('attrition.csv')

# %% [markdown]
# ### Categorical binning of the variable DistanceFromHome,Age and Total Working Years.

# %%
attr.DistanceFromHome.describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
DistanceFromHome_ranges = ["({0} - {1})".format(DistanceFromHome, DistanceFromHome+4) for DistanceFromHome in range(1,29,5)]
DistanceFromHome_ranges
# Out:
# ['(1 - 5)', '(6 - 10)', '(11 - 15)', '(16 - 20)', '(21 - 25)', '(26 - 30)']

# %%
count_DistanceFromHome_ranges = len(DistanceFromHome_ranges)
count_DistanceFromHome_ranges
# Out:
# 6

# %%
attr['DistanceFromHome_ranges'] = pd.cut(x=attr['DistanceFromHome'],bins = count_DistanceFromHome_ranges,labels = DistanceFromHome_ranges)

# %%
TotalWorkingYears_ranges = ["({0} - {1})".format(TotalWorkingYears, TotalWorkingYears+5) for TotalWorkingYears in range(0,40,5)]
TotalWorkingYears_ranges
# Out:
# ['(0 - 5)',
#  '(5 - 10)',
#  '(10 - 15)',
#  '(15 - 20)',
#  '(20 - 25)',
#  '(25 - 30)',
#  '(30 - 35)',
#  '(35 - 40)']

# %%
count_TotalWorkingYears_ranges = len(TotalWorkingYears_ranges)
count_TotalWorkingYears_ranges
# Out:
# 8

# %%
attr['TotalWorkingYears_ranges'] = pd.cut(x=attr['TotalWorkingYears'],bins = count_TotalWorkingYears_ranges,labels = TotalWorkingYears_ranges)

# %%
attr.head()
# Out:
#    Age  Attrition     BusinessTravel              Department EducationField  \
# 0   41          1      Travel_Rarely                   Sales  Life Sciences
# 1   49          0  Travel_Frequently  Research & Development  Life Sciences
# 2   37          1      Travel_Rarely  Research & Development          Other
# 3   33          0  Travel_Frequently  Research & Development  Life Sciences
# 4   27          0      Travel_Rarely  Research & Development        Medical
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
#
# ...

# %% [markdown]
# ### Bivariate Analysis of Attrition given department.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr.Department,columns= attr.Attrition)
table
# Out:
# Attrition                 0    1
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition                   0      1
# Department
# Human Resources         80.95  19.05
# Research & Development  86.16  13.84
# Sales                   79.37  20.63

# %% [markdown]
# ### Bivariate Analysis of Attrition given department.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr.Department,columns= attr.Attrition)
table
# Out:
# Attrition                 0    1
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
print(attr.Attrition.value_counts())
print(attr.Department.value_counts())
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    1233
# 1     237
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition                   0      1
# Department
# Human Resources         80.95  19.05
# Research & Development  86.16  13.84
# Sales                   79.37  20.63

# %%
 x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - So here we can see that the maximum attrition is in the <b>Sales</b> department.

# %% [markdown]
# #### Now we would like to check what is causing these 20% people in the sales department to leave the job.

# %% [markdown]
# ### Bivariate Analysis of Department given Environment Satsfaction.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr.Department,columns= attr.EnvironmentSatisfaction)
table
# Out:
# EnvironmentSatisfaction    1    2    3    4
# Department
# Human Resources           11   12   26   14
# Research & Development   187  177  292  305
# Sales                     86   98  135  127

# %%
print(attr.Department.value_counts())
print(attr.EnvironmentSatisfaction.value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# EnvironmentSatisfaction
# 1    284
# 2    287
# 3    453
# 4    446
# dtype: int64

# %%
round(table.div(rowtotal,axis=0)*100,2)
# Out:
# EnvironmentSatisfaction      1      2      3      4
# Department
# Human Resources          17.46  19.05  41.27  22.22
# Research & Development   19.46  18.42  30.39  31.74
# Sales                    19.28  21.97  30.27  28.48

# %%
x = round(table.div(rowtotal,axis=0)*100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - Here we can see the **Environment Satisfaction** given a particular department.
# - Here if we see the proportions of low and medium given sales totals to around **41.25%** which is higher than the other 2 departments.
# - The proportions of High and very high given sales totals to around **58%** which is lesser than the other two Departments.
# - Thus we can conclude here that out of the three departments the employees in the sales department have less Environment satisfaction as compared to the other two departments.
# - <b>Thus the sales dept is affecting Environment satisfaction the most

# %% [markdown]
# # Analysis based on the Sales Department.

# %% [markdown]
# ### Bivariate analysis between environment satisfation and Attrition within the sales department.

# %%
attr_sales = attr[attr.Department == 'Sales']

# %%
attr_sales.head()
# Out:
#     Age BusinessTravel Department EducationField  EnvironmentSatisfaction  \
# 0    41  Travel_Rarely      Sales  Life Sciences                        2
# 18   53  Travel_Rarely      Sales  Life Sciences                        1
# 21   36  Travel_Rarely      Sales  Life Sciences                        3
# 27   42  Travel_Rarely      Sales      Marketing                        3
# 29   46  Travel_Rarely      Sales      Marketing                        2
#
#     Gender  JobInvolvement  JobLevel  JobSatisfaction MaritalStatus  ...  \
# 0   Female               3         2                4        Single  ...
# 18  Female               2         4                4       Married  ...
# 21    Male               2         1                1        Single  ...
# 27    Male               3         2                2       Married  ...
# 29  Female               3         5                1        Single  ...
#
#     WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# ...

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_sales.EnvironmentSatisfaction,columns= attr_sales.Attrition)
table.index = ['Low','Medium','High','Very High']
table
# Out:
# Attrition    0   1
# Low         61  25
# Medium      76  22
# High       113  22
# Very High  104  23

# %%
print(attr_sales.EnvironmentSatisfaction.value_counts())
print(attr_sales.Attrition.value_counts())
# Out:
# 3    135
# 4    127
# 2     98
# 1     86
# Name: EnvironmentSatisfaction, dtype: int64
# 0    354
# 1     92
# Name: Attrition, dtype: int64

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Low           86
# Medium        98
# High         135
# Very High    127
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    354
# 1     92
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition      0      1
# Low        70.93  29.07
# Medium     77.55  22.45
# High       83.70  16.30
# Very High  81.89  18.11

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - Thus within the **Sales Dept** we have **29.07%** of the people leaving due to **low environment Satisfaction**.
# - Now we can check which Gender within the sales department that have low envronment satisfaction are leaving the company the most.

# %% [markdown]
# ### Bivariate analysis of Gender and attrition of the employees who have low environment satisfaction within the sales department.

# %%
attr_sales_low_env_satis = attr_sales[attr_sales.EnvironmentSatisfaction == 1]

# %%
attr_sales_low_env_satis.head()
# Out:
#     Age     BusinessTravel Department EducationField  EnvironmentSatisfaction  \
# 18   53      Travel_Rarely      Sales  Life Sciences                        1
# 36   50      Travel_Rarely      Sales      Marketing                        1
# 48   46  Travel_Frequently      Sales      Marketing                        1
# 63   59      Travel_Rarely      Sales  Life Sciences                        1
# 70   59  Travel_Frequently      Sales  Life Sciences                        1
#
#     Gender  JobInvolvement  JobLevel  JobSatisfaction MaritalStatus  ...  \
# 18  Female               2         4                4       Married  ...
# 36    Male               2         1                3       Married  ...
# 48    Male               3         2                4        Single  ...
# 63  Female               3         3                1        Single  ...
# 70  Female               2         2                3        Single  ...
#
#     WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# ...

# %%
attr_sales_low_env_satis.Gender.value_counts()
# Out:
# Male      50
# Female    36
# Name: Gender, dtype: int64

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_sales_low_env_satis.Gender,columns= attr_sales_low_env_satis.Attrition)
table
# Out:
# Attrition   0   1
# Gender
# Female     24  12
# Male       37  13

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Gender
# Female    36
# Male      50
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    61
# 1    25
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition      0      1
# Gender
# Female     66.67  33.33
# Male       74.00  26.00

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - So thus here we can see that **33.33 %** of **female** in the **sales department** with **low environment satisfaction** are leaving the company.
# - Thus there is a higher attrition in female employees having low environment satisfaction in the sales department.

# %% [markdown]
# ### Bivariate analysis of attrition given business travel within the employees of the sales dept having low environment satisfcation.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_sales_low_env_satis.BusinessTravel,columns= attr_sales_low_env_satis.Attrition)
table
# Out:
# Attrition           0   1
# BusinessTravel
# Non-Travel          9   1
# Travel_Frequently   8   6
# Travel_Rarely      44  18

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# BusinessTravel
# Non-Travel           10
# Travel_Frequently    14
# Travel_Rarely        62
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    61
# 1    25
# dtype: int64

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - Here we can see that there is **42.86%** attrition of the employees who travel frequently within the sales dept and having **low environment satisfaction**

# %% [markdown]
# ### Bivariate analysis of age ranges and attrition within the females of the sales department having low environment satisfaction.

# %%
attr_sales_low_env_satis_female = attr_sales[(attr_sales.EnvironmentSatisfaction == 1) & (attr_sales.Gender == 'Female')]

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_sales_low_env_satis_female.Age_ranges,columns= attr_sales_low_env_satis_female.Attrition)
table
# Out:
# Attrition   0  1
# Age_ranges
# (18 - 25)   2  3
# (25 - 32)   4  1
# (32 - 39)   9  4
# (39 - 46)   2  3
# (46 - 53)   4  1
# (53 - 60)   3  0

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Age_ranges
# (18 - 25)     5
# (25 - 32)     5
# (32 - 39)    13
# (39 - 46)     5
# (46 - 53)     5
# (53 - 60)     3
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    24
# 1    12
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition        0      1
# Age_ranges
# (18 - 25)    40.00  60.00
# (25 - 32)    80.00  20.00
# (32 - 39)    69.23  30.77
# (39 - 46)    40.00  60.00
# (46 - 53)    80.00  20.00
# (53 - 60)   100.00   0.00

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - Here we can see the **females** from the **sales department** having **environment satisfaction low** within the age ranges of **18-25 and 39-46** are leaving the company the most i.e 60%
# - This is very unusual as usually women who are more aged should be affected by Environment Satisfaction.

# %% [markdown]
# ### Bivariate analysis b/w attrition given business travel.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr.BusinessTravel,columns= attr.Attrition)
table
# Out:
# Attrition            0    1
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# BusinessTravel
# Non-Travel            150
# Travel_Frequently     277
# Travel_Rarely        1043
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    1233
# 1     237
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition              0      1
# BusinessTravel
# Non-Travel         92.00   8.00
# Travel_Frequently  75.09  24.91
# Travel_Rarely      85.04  14.96

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - So here we can see that within **sales** the **24.91%** people who are travelling frequently are leaving the company.

# %%
attr_sales_travelfreq =attr_sales[attr_sales.BusinessTravel == 'Travel_Frequently']

# %%
attr_sales_travelfreq
# Out:
#       Age     BusinessTravel Department    EducationField  \
# 39     33  Travel_Frequently      Sales     Life Sciences
# 43     27  Travel_Frequently      Sales     Life Sciences
# 48     46  Travel_Frequently      Sales         Marketing
# 56     35  Travel_Frequently      Sales     Life Sciences
# 70     59  Travel_Frequently      Sales     Life Sciences
# ...   ...                ...        ...               ...
# 1365   29  Travel_Frequently      Sales  Technical Degree
# 1395   31  Travel_Frequently      Sales         Marketing
# 1438   23  Travel_Frequently      Sales         Marketing
# 1452   50  Travel_Frequently      Sales     Life Sciences
# 1468   49  Travel_Frequently      Sales           Medical
#
#       EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 39                          3  Female               4         2
# 43                          4    Male               3         3
# 48                          1    Male               3         2
# ...

# %% [markdown]
# ### Bivariate Analysis of Attrition given Gender of all employees within sales department who travel frequently.

# %%
attr_sales_travelfreq.Gender.value_counts()
# Out:
# Male      46
# Female    38
# Name: Gender, dtype: int64

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_sales_travelfreq.Gender,columns= attr.Attrition)
table
# Out:
# Attrition   0   1
# Gender
# Female     24  14
# Male       32  14

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Gender
# Female    38
# Male      46
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    56
# 1    28
# dtype: int64

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - So here we can see that the **36%** of the **females** within the **sales department** who **travel frequently** are leaving the company.
#
# - So now within 36% of females who are leaving the company we want to see the age range of these 36% of females.

# %%
attr_sales_travelfreq_females =attr_sales[(attr_sales.BusinessTravel == 'Travel_Frequently') & (attr_sales.Gender == 'Female')]

# %%
attr_sales_travelfreq_females.head()
# Out:
#      Age     BusinessTravel Department    EducationField  \
# 39    33  Travel_Frequently      Sales     Life Sciences
# 70    59  Travel_Frequently      Sales     Life Sciences
# 117   36  Travel_Frequently      Sales  Technical Degree
# 131   50  Travel_Frequently      Sales         Marketing
# 154   32  Travel_Frequently      Sales         Marketing
#
#      EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 39                         3  Female               4         2
# 70                         1  Female               2         2
# 117                        2  Female               3         3
# 131                        3  Female               3         3
# 154                        2  Female               3         3
#
#      JobSatisfaction MaritalStatus  ...  WorkLifeBalance YearsAtCompany  \
# 39                 1       Married  ...                3              5
# 70                 3        Single  ...                2              4
# ...

# %%
attr_sales_travelfreq_females.Age_ranges.value_counts()
# Out:
# (25 - 32)    12
# (32 - 39)    10
# (46 - 53)     5
# (39 - 46)     4
# (18 - 25)     4
# (53 - 60)     3
# Name: Age_ranges, dtype: int64

# %% [markdown]
# - Now among these females from the sales department who travel frequently we want to see what age group is leaving the company more.

# %% [markdown]
# ### Bivariate analysis of Age range and Attrition within the female employees of the sales dept who travel frequently.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_sales_travelfreq_females.Age_ranges,columns= attr_sales_travelfreq_females.Attrition)
table
# Out:
# Attrition   0  1
# Age_ranges
# (18 - 25)   0  4
# (25 - 32)   7  5
# (32 - 39)   8  2
# (39 - 46)   3  1
# (46 - 53)   3  2
# (53 - 60)   3  0

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Age_ranges
# (18 - 25)     4
# (25 - 32)    12
# (32 - 39)    10
# (39 - 46)     4
# (46 - 53)     5
# (53 - 60)     3
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    24
# 1    14
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition        0       1
# Age_ranges
# (18 - 25)     0.00  100.00
# (25 - 32)    58.33   41.67
# (32 - 39)    80.00   20.00
# (39 - 46)    75.00   25.00
# (46 - 53)    60.00   40.00
# (53 - 60)   100.00    0.00

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - So thus here we can see that within the **females** from the **sales department** who **travel frequently** with age range **18-25** are leaving the company followed by age range of **25-32**.
# - This is very unusual as the older the employees more difficult it gets for them to travel frequently but here it seems like the older employees leave the company where as the younger employee stay.

# %% [markdown]
# ### Attrition given overtime within the sales department.

# %%
attr_sales
# Out:
#       Age     BusinessTravel Department EducationField  \
# 0      41      Travel_Rarely      Sales  Life Sciences
# 18     53      Travel_Rarely      Sales  Life Sciences
# 21     36      Travel_Rarely      Sales  Life Sciences
# 27     42      Travel_Rarely      Sales      Marketing
# 29     46      Travel_Rarely      Sales      Marketing
# ...   ...                ...        ...            ...
# 1454   45      Travel_Rarely      Sales  Life Sciences
# 1461   50      Travel_Rarely      Sales      Marketing
# 1462   39      Travel_Rarely      Sales      Marketing
# 1464   26      Travel_Rarely      Sales          Other
# 1468   49  Travel_Frequently      Sales        Medical
#
#       EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0                           2  Female               3         2
# 18                          1  Female               2         4
# 21                          3    Male               2         1
# ...

# %%
attr_sales.OverTime.value_counts()
# Out:
# No     318
# Yes    128
# Name: OverTime, dtype: int64

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_sales.OverTime,columns= attr_sales.Attrition)
table
# Out:
# Attrition    0   1
# OverTime
# No         274  44
# Yes         80  48

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# OverTime
# No     318
# Yes    128
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    354
# 1     92
# dtype: int64

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - So here we can see that **37.50%** of the people within the **sales department** are leaving due to **overtime.**

# %% [markdown]
# ## Conclusion based on the Analysis on the Sales Department.
#
# ### Variables affecting Attrtion:
#
# - Environment Satisfaction:Low -> Gender:Female ->Age Range:18-25,39-46
#
# - Gender: Female -> travel frequently -> Age range:18-25
#
# - Overtime
#
# This is attrition because of **SALES Department**

# %% [markdown]
# # Analysis Based on the HR Department.

# %% [markdown]
# ### Bivariate Analysis of Department and Distance from home.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr.Department,columns= attr.DistanceFromHome_ranges)
table
# Out:
# DistanceFromHome_ranges  (1 - 5)  (6 - 10)  (11 - 15)  (16 - 20)  (21 - 25)  \
# Department
# Human Resources               29        17          3          4          5
# Research & Development       414       256         74         70         78
# Sales                        189       121         38         26         34
#
# DistanceFromHome_ranges  (26 - 30)
# Department
# Human Resources                  5
# Research & Development          69
# Sales                           38

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# DistanceFromHome_ranges
# (1 - 5)      632
# (6 - 10)     394
# (11 - 15)    115
# (16 - 20)    100
# (21 - 25)    117
# (26 - 30)    112
# dtype: int64

# %%
 round(table.div(rowtotal,axis=0) *100,2)
# Out:
# DistanceFromHome_ranges  (1 - 5)  (6 - 10)  (11 - 15)  (16 - 20)  (21 - 25)  \
# Department
# Human Resources            46.03     26.98       4.76       6.35       7.94
# Research & Development     43.08     26.64       7.70       7.28       8.12
# Sales                      42.38     27.13       8.52       5.83       7.62
#
# DistanceFromHome_ranges  (26 - 30)
# Department
# Human Resources               7.94
# Research & Development        7.18
# Sales                         8.52

# %%
attr_HR = attr[attr.Department == 'Human Resources']

# %%
attr_HR.head()
# Out:
#      Age BusinessTravel       Department   EducationField  \
# 79    46  Travel_Rarely  Human Resources          Medical
# 100   37  Travel_Rarely  Human Resources  Human Resources
# 105   59     Non-Travel  Human Resources  Human Resources
# 112   54     Non-Travel  Human Resources  Human Resources
# 134   26  Travel_Rarely  Human Resources    Life Sciences
#
#      EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 79                         2    Male               3         2
# 100                        3    Male               3         1
# 105                        3  Female               2         5
# 112                        4  Female               4         4
# 134                        3  Female               3         1
#
#      JobSatisfaction MaritalStatus  ...  WorkLifeBalance YearsAtCompany  \
# 79                 2      Divorced  ...                3              4
# 100                1      Divorced  ...                3              3
# ...

# %% [markdown]
# ### Attrition given Distance from home within the HR dept.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_HR.DistanceFromHome_ranges,columns= attr_HR.Attrition)

table
# Out:
# Attrition                 0  1
# DistanceFromHome_ranges
# (1 - 5)                  27  2
# (6 - 10)                 14  3
# (11 - 15)                 2  1
# (16 - 20)                 2  2
# (21 - 25)                 1  4
# (26 - 30)                 5  0

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# DistanceFromHome_ranges
# (1 - 5)      29
# (6 - 10)     17
# (11 - 15)     3
# (16 - 20)     4
# (21 - 25)     5
# (26 - 30)     5
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    51
# 1    12
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition                     0      1
# DistanceFromHome_ranges
# (1 - 5)                   93.10   6.90
# (6 - 10)                  82.35  17.65
# (11 - 15)                 66.67  33.33
# (16 - 20)                 50.00  50.00
# (21 - 25)                 20.00  80.00
# (26 - 30)                100.00   0.00

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
ax = x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )


rects = ax.patches

# Make some labels.
#labels = ["label%d" % i for i in range(len(rects))]
labels = [93.10,82.35,66.67,50.00,20.00,100.00,6.90,17.65,33.33,50.00,80.00]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')

# %% [markdown]
# - Within the **HR dept** we can see a clear increase in attrition as the distance from home increases.

# %%
attr.boxplot(column = 'MonthlyIncome',notch = True,
             by = 'Department',
             grid=False,
             figsize= (6,4),
             rot = 90
             )         #The angle by which you want to rotate the labels.

plt.ylabel('MonthlyIncome', fontsize=12)
plt.title('Boxplot of Weight', fontsize=14)

plt.show()

# %% [markdown]
# - The monthly income within the **HR dept** is the least.**50 %** employees recieve salaries less than **3500.**

# %%
attr_HR = attr[attr.Department == 'Human Resources']

# %%
attr_HR.boxplot(column = 'MonthlyIncome',notch = True,
             by = 'Attrition',
             grid=False,
             figsize= (9,6),
             rot = 90
             )         #The angle by which you want to rotate the labels.

plt.ylabel('MonthlyIncome', fontsize=12)
plt.title('Boxplot of Monthly Income', fontsize=14)

plt.show()

# %% [markdown]
# - Within the **HR dept** we can see there is maximum attrition in the employees with salaries less than **3000.**

# %%
attr_HR.head()
# Out:
#      Age BusinessTravel       Department   EducationField  \
# 79    46  Travel_Rarely  Human Resources          Medical
# 100   37  Travel_Rarely  Human Resources  Human Resources
# 105   59     Non-Travel  Human Resources  Human Resources
# 112   54     Non-Travel  Human Resources  Human Resources
# 134   26  Travel_Rarely  Human Resources    Life Sciences
#
#      EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 79                         2    Male               3         2
# 100                        3    Male               3         1
# 105                        3  Female               2         5
# 112                        4  Female               4         4
# 134                        3  Female               3         1
#
#      JobSatisfaction MaritalStatus  ...  WorkLifeBalance YearsAtCompany  \
# 79                 2      Divorced  ...                3              4
# 100                1      Divorced  ...                3              3
# ...

# %%
attr_HR_DFH16to25 = attr[(attr.Department == 'Human Resources') & (attr.DistanceFromHome >= 16)&(attr.DistanceFromHome <= 25) ]

# %%
attr_HR_DFH16to25.describe()
# Out:
#              Age  EnvironmentSatisfaction  JobInvolvement   JobLevel  \
# count  10.000000                 10.00000       10.000000  10.000000
# mean   32.200000                  2.70000        2.700000   1.600000
# std     9.795691                  1.05935        0.823273   0.966092
# min    24.000000                  1.00000        1.000000   1.000000
# 25%    26.000000                  2.00000        2.250000   1.000000
# 50%    28.000000                  2.50000        3.000000   1.000000
# 75%    33.250000                  3.75000        3.000000   2.500000
# max    54.000000                  4.00000        4.000000   3.000000
#
#        JobSatisfaction  MonthlyIncome  TotalWorkingYears  WorkLifeBalance  \
# count        10.000000      10.000000          10.000000        10.000000
# mean          2.000000    4604.500000           6.900000         2.900000
# std           0.816497    3507.079736           4.794673         0.567646
# ...

# %%
attr_HR_DFH16to25
# Out:
#       Age     BusinessTravel       Department   EducationField  \
# 134    26      Travel_Rarely  Human Resources    Life Sciences
# 440    34  Travel_Frequently  Human Resources  Human Resources
# 453    26  Travel_Frequently  Human Resources    Life Sciences
# 510    54      Travel_Rarely  Human Resources          Medical
# 759    45      Travel_Rarely  Human Resources          Medical
# 1005   29      Travel_Rarely  Human Resources            Other
# 1222   24      Travel_Rarely  Human Resources  Human Resources
# 1297   26      Travel_Rarely  Human Resources          Medical
# 1312   31      Travel_Rarely  Human Resources  Human Resources
# 1379   27  Travel_Frequently  Human Resources  Human Resources
#
#       EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 134                         3  Female               3         1
# 440                         2  Female               3         3
# 453                         2  Female               3         1
# ...

# %%
attr_HR_DFH16to25.MonthlyIncome.describe()
# Out:
# count       10.000000
# mean      4604.500000
# std       3507.079736
# min       1555.000000
# 25%       2318.000000
# 50%       2902.500000
# 75%       6730.000000
# max      10725.000000
# Name: MonthlyIncome, dtype: float64

# %%
attr.MonthlyIncome.describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
attr_HR_DFH16to25.boxplot(column = 'MonthlyIncome',notch = True,
             by = 'Attrition',
             grid=False,
             figsize= (12,7),
             rot = 90
             )         #The angle by which you want to rotate the labels.

plt.ylabel('MonthlyIncome', fontsize=12)
plt.title('Boxplot of Monthly Income', fontsize=14)

plt.show()

# %% [markdown]
# ## Conclusion based on the Analysis on the HR Department.
#
# ### Variables affecting Attrtion:
#
# - Distance From Home: 16-25
#
# - Monthly Income: Almost all employees recieving Less than 3500 except few outliers.
#
# - Distance From Home : 16-25 -> Monthly Income < 3000
#
#
# This is attrition because of **HR Department**

# %% [markdown]
# ### Bivariate Analysis of Department and  WorkLifeBalance

# %%
attr.WorkLifeBalance.value_counts()
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr.Department,columns= attr.WorkLifeBalance)
table.columns = ['Low','Medium','High','Very High']
table
# Out:
#                         Low  Medium  High  Very High
# Department
# Human Resources           4       7    42         10
# Research & Development   60     235   575         91
# Sales                    16     102   276         52

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Low           80
# Medium       344
# High         893
# Very High    153
# dtype: int64

# %%
round(table.div(rowtotal,axis=0) *100,2)
# Out:
#                          Low  Medium   High  Very High
# Department
# Human Resources         6.35   11.11  66.67      15.87
# Research & Development  6.24   24.45  59.83       9.47
# Sales                   3.59   22.87  61.88      11.66

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - So here looking at the numbers we can see that the <b> Research and development department is affecting the Worklife balance.
# - After RnD, sales is the second to affect Worklife balance.

# %% [markdown]
# # Analysis Based on the RnD Department.

# %%
attr_RnD = attr[attr.Department == 'Research & Development']

# %%
attr_RnD.head()
# Out:
#    Age     BusinessTravel              Department EducationField  \
# 1   49  Travel_Frequently  Research & Development  Life Sciences
# 2   37      Travel_Rarely  Research & Development          Other
# 3   33  Travel_Frequently  Research & Development  Life Sciences
# 4   27      Travel_Rarely  Research & Development        Medical
# 5   32  Travel_Frequently  Research & Development  Life Sciences
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
# 5                        4    Male               3         1                4
#
#   MaritalStatus  ...  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# ...

# %% [markdown]
# ### Bivariate analysis between Attrition given worklife balance within the RnD dept.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_RnD.WorkLifeBalance,columns= attr_RnD.Attrition)
table.index = ['Low','Medium','High','Very High']
table
# Out:
# Attrition    0   1
# Low         41  19
# Medium     203  32
# High       507  68
# Very High   77  14

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# Low           60
# Medium       235
# High         575
# Very High     91
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    828
# 1    133
# dtype: int64

# %%
 round(table.div(rowtotal,axis=0) *100,2)
# Out:
# Attrition      0      1
# Low        68.33  31.67
# Medium     86.38  13.62
# High       88.17  11.83
# Very High  84.62  15.38

# %%
x = round(table.div(rowtotal,axis=0) *100,2)

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %%
#x.plot(kind = 'bar' ,rot=0 , figsize = [16,5],)

#plt.figure(figsize=(56, 18))
ax = x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )


rects = ax.patches

# Make some labels.
#labels = ["label%d" % i for i in range(len(rects))]
labels = [68.33,86.38,88.17,84.62,31.67,13.62,11.83,15.38]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')

# %% [markdown]
# - Here as we can see the employees within the **RnD dept** suffering from **low worklife balance** and are leaving the company is **31.67%.**

# %%
attr_RnD_lowWLB = attr[(attr.Department == 'Research & Development')&(attr.WorkLifeBalance == 1)]

# %%
attr_RnD_lowWLB.head()
# Out:
#      Age BusinessTravel              Department    EducationField  \
# 95    54  Travel_Rarely  Research & Development  Technical Degree
# 153   45  Travel_Rarely  Research & Development     Life Sciences
# 161   27     Non-Travel  Research & Development           Medical
# 162   28  Travel_Rarely  Research & Development           Medical
# 163   57  Travel_Rarely  Research & Development     Life Sciences
#
#      EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 95                         1  Female               3         3
# 153                        2    Male               3         2
# 161                        4    Male               3         1
# 162                        3    Male               3         1
# 163                        3    Male               4         3
#
#      JobSatisfaction MaritalStatus  ...  WorkLifeBalance YearsAtCompany  \
# 95                 3       Married  ...                1              4
# ...

# %% [markdown]
# ### Bivariate analysis of Attrition given Marital status of employees within the RnD dept having low worklife balance.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_RnD_lowWLB.MaritalStatus,columns= attr_RnD_lowWLB.Attrition)
table
# Out:
# Attrition       0   1
# MaritalStatus
# Divorced        9   3
# Married        22   6
# Single         10  10

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# MaritalStatus
# Divorced    12
# Married     28
# Single      20
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    41
# 1    19
# dtype: int64

# %%
round(table.div(rowtotal,axis=0)*100,2)
# Out:
# Attrition          0      1
# MaritalStatus
# Divorced       75.00  25.00
# Married        78.57  21.43
# Single         50.00  50.00

# %%
x = round(table.div(rowtotal,axis=0)*100,2)

# %%
ax = x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )


rects = ax.patches

# Make some labels.
#labels = ["label%d" % i for i in range(len(rects))]
labels = [75.00,78.57,50.00,25.00,21.43,50.00]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')

# %% [markdown]
# - So here we can see that the employees in the **RnD dept** suffering from **low Worklifebalance** and are **Single** have an attrition rate of **50%**, which is maximum as compared to the other two levels.
# - This is quite unusual as we may have expected Married employees to  affect of worklife balance more as they have more responsibilities.

# %% [markdown]
# ### Bivariate analysis of Attrition given overtime within the employees of the  RnD dept having low Worklife Balance.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_RnD_lowWLB.OverTime,columns= attr_RnD_lowWLB.Attrition)
table
# Out:
# Attrition   0   1
# OverTime
# No         33  10
# Yes         8   9

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# OverTime
# No     43
# Yes    17
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    41
# 1    19
# dtype: int64

# %%
round(table.div(rowtotal,axis=0)*100,2)
# Out:
# Attrition      0      1
# OverTime
# No         76.74  23.26
# Yes        47.06  52.94

# %%
 x = round(table.div(rowtotal,axis=0)*100,2)

# %%
ax = x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )


rects = ax.patches

# Make some labels.
#labels = ["label%d" % i for i in range(len(rects))]
labels = [76.74,47.06,23.26,52.94]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')

# %%
x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )

# %% [markdown]
# - Here we can see that **52.94%** of the within the **RnD dept** who are suffering from **Low Worklife balance** are leaving the company due to **Overtime**.
# - Through this we can conclude that Overtime is affecting the worklife balance within the RnD dept due to which the employees are leaving the company.

# %% [markdown]
# ### Bivariate analysis of Attrition given JobLevel within the employees of the  RnD dept having low Worklife Balance.

# %%
#C. Bi-variate Frequency Distribution Table
table = pd.crosstab(attr_RnD_lowWLB.JobLevel,columns= attr_RnD_lowWLB.Attrition)
table
# Out:
# Attrition   0   1
# JobLevel
# 1          16  17
# 2          14   2
# 3           7   0
# 4           3   0
# 5           1   0

# %%
#Finding the row sums
rowtotal = table.sum(axis=1)
rowtotal
# Out:
# JobLevel
# 1    33
# 2    16
# 3     7
# 4     3
# 5     1
# dtype: int64

# %%
#Finding the col-sums
coltotal = table.sum(axis=0)
coltotal
# Out:
# Attrition
# 0    41
# 1    19
# dtype: int64

# %%
round(table.div(rowtotal,axis=0)*100,2)
# Out:
# Attrition       0      1
# JobLevel
# 1           48.48  51.52
# 2           87.50  12.50
# 3          100.00   0.00
# 4          100.00   0.00
# 5          100.00   0.00

# %%
x = round(table.div(rowtotal,axis=0)*100,2)

# %%
ax = x.plot(kind = 'bar' ,rot=0 , figsize = [16,5] )


rects = ax.patches

# Make some labels.
#labels = ["label%d" % i for i in range(len(rects))]
labels = [48.48,87.50,100.00,100.00,100.00,51.52,12.50,]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')

# %% [markdown]
# - Here we can see that the employees within the **RnD dept** with **low work life balance** and having **Joblevel 1** are leaving the company the most i.e **51.52%** employees with **Joblevel 1** are leaving.
# - Thus here we can conclude that the Job level of the employees is affecting the Worklife balance due to which employees within the RnD dept are leaving the company.

# %% [markdown]
# ## Conclusion based on the Analysis on the Research and Development Department.
#
# ### Variables affecting Attrtion:
#
# - Worklifebalance: Low
#
# - Worklifebalance: Low -> Marital Status: Single
#
# - Worklifebalance: Low -> Overtime:Yes
#
# - Worklifebalance: Low -> Joblevel:1
#
# This is attrition because of **Research and Development Department**
